# %%
df = pd.read_csv("data/auto-mpg.csv")
df.head(3)
# Out:
#     MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 0  18.0          8         307.0       130.0  3504.0          12.0
# 1  15.0          8         350.0       165.0  3693.0          11.5
# 2  18.0          8         318.0       150.0  3436.0          11.0
#
#    Model Year  Origin
# 0          70       1
# 1          70       1
# 2          70       1

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (392, 8)

# %%
t = df['MPG']
t.head()
# Out:
# 0    18.0
# 1    15.0
# 2    18.0
# 3    16.0
# 4    17.0
# Name: MPG, dtype: float64

# %%
x = df.drop('MPG', axis=1)
x.head()
# Out:
#    Cylinders  Displacement  Horsepower  Weight  Acceleration  Model Year  \
# 0          8         307.0       130.0  3504.0          12.0          70
# 1          8         350.0       165.0  3693.0          11.5          70
# 2          8         318.0       150.0  3436.0          11.0          70
# 3          8         304.0       150.0  3433.0          12.0          70
# 4          8         302.0       140.0  3449.0          10.5          70
#
#    Origin
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
# 並び替え
df.sort_values('Weight').head()
# Out:
#       MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 53   35.0          4          72.0        69.0  1613.0          18.0
# 142  31.0          4          76.0        52.0  1649.0          16.5
# 339  39.1          4          79.0        58.0  1755.0          16.9
# 341  35.1          4          81.0        60.0  1760.0          16.1
# 52   31.0          4          71.0        65.0  1773.0          19.0
#
#      Model Year  Origin
# 53           71       3
# 142          74       3
# 339          81       3
# 341          81       3
# 52           71       3

# %%
df.sort_values('Weight', ascending=False).head()
# Out:
#       MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 43   13.0          8         400.0       175.0  5140.0          12.0
# 102  11.0          8         400.0       150.0  4997.0          14.0
# 41   12.0          8         383.0       180.0  4955.0          11.5
# 89   12.0          8         429.0       198.0  4952.0          11.5
# 94   12.0          8         455.0       225.0  4951.0          11.0
#
#      Model Year  Origin
# 43           71       1
# 102          73       1
# 41           71       1
# 89           73       1
# 94           73       1

# %%
origin = df['Origin']
df = df.drop('Origin', axis=1)
df.head()
# Out:
#     MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  Model Year
# 0  18.0          8         307.0       130.0  3504.0          12.0          70
# 1  15.0          8         350.0       165.0  3693.0          11.5          70
# 2  18.0          8         318.0       150.0  3436.0          11.0          70
# 3  16.0          8         304.0       150.0  3433.0          12.0          70
# 4  17.0          8         302.0       140.0  3449.0          10.5          70

# %%
df['Origin'] = origin
df.head()
# Out:
#     MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 0  18.0          8         307.0       130.0  3504.0          12.0
# 1  15.0          8         350.0       165.0  3693.0          11.5
# 2  18.0          8         318.0       150.0  3436.0          11.0
# 3  16.0          8         304.0       150.0  3433.0          12.0
# 4  17.0          8         302.0       140.0  3449.0          10.5
#
#    Model Year  Origin
# 0          70       1
# 1          70       1
# 2          70       1
# 3          70       1
# 4          70       1

# %%
df[df['Origin'] == 3].head()
# Out:
#      MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 14  24.0          4         113.0        95.0  2372.0          15.0
# 18  27.0          4          97.0        88.0  2130.0          14.5
# 29  27.0          4          97.0        88.0  2130.0          14.5
# 31  25.0          4         113.0        95.0  2228.0          14.0
# 52  31.0          4          71.0        65.0  1773.0          19.0
#
#     Model Year  Origin
# 14          70       3
# 18          70       3
# 29          71       3
# 31          71       3
# 52          71       3

# %%
df[(df['Origin'] == 3) & (df['Weight'] >= 2000)].head()
# Out:
#      MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 14  24.0          4         113.0        95.0  2372.0          15.0
# 18  27.0          4          97.0        88.0  2130.0          14.5
# 29  27.0          4          97.0        88.0  2130.0          14.5
# 31  25.0          4         113.0        95.0  2228.0          14.0
# 56  24.0          4         113.0        95.0  2278.0          15.5
#
#     Model Year  Origin
# 14          70       3
# 18          70       3
# 29          71       3
# 31          71       3
# 56          72       3

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df['Origin'].value_counts()
# Out:
# 1    245
# 3     79
# 2     68
# Name: Origin, dtype: int64

# %%
x = df['Origin'].value_counts().index

height = df['Origin'].value_counts().values

x, height
# Out:
# (Int64Index([1, 3, 2], dtype='int64'), array([245,  79,  68]))

# %%
plt.bar(x, height)
# Out:
# <BarContainer object of 3 artists>

# %%
plt.style.use('seaborn')
plt.bar(x, height)
# Out:
# <BarContainer object of 3 artists>

# %%
sns.countplot(x = 'Cylinders', data=df)
# Out:
# <AxesSubplot:xlabel='Cylinders', ylabel='count'>

# %%
import numpy as np

x = np.linspace(0, 10, 100)

x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
y = x + np.random.randn(100)
y
# Out:
# array([ 0.169678  , -1.41720123,  2.78688662,  1.36129037, -0.19064781,
#         1.54530792,  0.47057864,  0.15681913,  1.89717753,  0.07731567,
#         1.82056008,  2.34115069,  1.77748191,  2.17223313,  1.02501297,
#         2.35379135,  1.46467194,  0.47328013,  1.90548232,  0.88561922,
#         1.79267588,  3.51365768,  0.41412012,  2.75546923,  4.03171468,
#         3.21781585,  1.74205718,  3.35188996,  2.93911752,  1.44855046,
#         3.93951578,  4.72144931,  3.56135202,  2.79440914,  3.67534851,
#         4.32692927,  4.47267371,  2.83244829,  5.59221864,  6.06628679,
#         4.56429232,  3.40304083,  4.05112954,  2.47735658,  5.35078116,
#         4.02883468,  4.05522656,  5.24943389,  5.66348264,  5.73529777,
#         6.58370151,  5.95968451,  5.49566799,  6.45789307,  5.47604832,
#         7.26783831,  5.13683209,  6.74376401,  6.45702841,  7.16628949,
#         5.12593887,  6.58264855,  6.67702291,  5.92077495,  6.47799481,
# ...

# %%
plt.plot(x, y)

# %%
plt.hist(df['Acceleration'], bins=10)
# Out:
# (array([ 6., 15., 50., 85., 91., 78., 44., 12.,  7.,  4.]),
#  array([ 8.  ,  9.68, 11.36, 13.04, 14.72, 16.4 , 18.08, 19.76, 21.44,
#         23.12, 24.8 ]),
#  <BarContainer object of 10 artists>)

# %%
sns.displot(df['Acceleration'], kde=False, bins=10)

# %%
sns.displot(df['Acceleration'], kde=True, bins=10)

# %%
plt.boxplot(df['Acceleration'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fb4165e7d90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fb4165e42b0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fb4165e4760>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fb4165e7ac0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fb4170a4b20>],
#  'means': []}

# %%
plt.scatter(df['Weight'], df['MPG'])

# %%
sns.jointplot(df['Weight'], df['MPG'])
# Out:
# /Users/hono/Desktop/python-datascience/env/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.pairplot(df)

# %%
df_corr = df.corr()

df_corr
# Out:
#                    MPG  Cylinders  Displacement  Horsepower    Weight  \
# MPG           1.000000  -0.777618     -0.805127   -0.778427 -0.832244
# Cylinders    -0.777618   1.000000      0.950823    0.842983  0.897527
# Displacement -0.805127   0.950823      1.000000    0.897257  0.932994
# Horsepower   -0.778427   0.842983      0.897257    1.000000  0.864538
# Weight       -0.832244   0.897527      0.932994    0.864538  1.000000
# Acceleration  0.423329  -0.504683     -0.543800   -0.689196 -0.416839
# Model Year    0.580541  -0.345647     -0.369855   -0.416361 -0.309120
# Origin        0.565209  -0.568932     -0.614535   -0.455171 -0.585005
#
#               Acceleration  Model Year    Origin
# MPG               0.423329    0.580541  0.565209
# Cylinders        -0.504683   -0.345647 -0.568932
# Displacement     -0.543800   -0.369855 -0.614535
# Horsepower       -0.689196   -0.416361 -0.455171
# Weight           -0.416839   -0.309120 -0.585005
# ...

# %%
sns.heatmap(df_corr, annot=True, cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#               MPG   Cylinders  Displacement  Horsepower       Weight  \
# count  392.000000  392.000000    392.000000  392.000000   392.000000
# mean    23.445918    5.471939    194.411990  104.469388  2977.584184
# std      7.805007    1.705783    104.644004   38.491160   849.402560
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.000000    4.000000    105.000000   75.000000  2225.250000
# 50%     22.750000    4.000000    151.000000   93.500000  2803.500000
# 75%     29.000000    8.000000    275.750000  126.000000  3614.750000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        Acceleration  Model Year      Origin
# count    392.000000  392.000000  392.000000
# mean      15.541327   75.979592    1.576531
# std        2.758864    3.683737    0.805518
# min        8.000000   70.000000    1.000000
# 25%       13.775000   73.000000    1.000000
# 50%       15.500000   76.000000    1.000000
# ...

# %%
# グループ化
df.groupby('Origin').mean()
# Out:
#               MPG  Cylinders  Displacement  Horsepower       Weight  \
# Origin
# 1       20.033469   6.277551    247.512245  119.048980  3372.489796
# 2       27.602941   4.161765    109.632353   80.558824  2433.470588
# 3       30.450633   4.101266    102.708861   79.835443  2221.227848
#
#         Acceleration  Model Year
# Origin
# 1          14.990204   75.591837
# 2          16.794118   75.676471
# 3          16.172152   77.443038

# %%
# クロス集計
pd.crosstab(df['Cylinders'], df['Origin'])
# Out:
# Origin       1   2   3
# Cylinders
# 3            0   0   4
# 4           69  61  69
# 5            0   3   0
# 6           73   4   6
# 8          103   0   0

# %%
# ピボットテーブル
pd.pivot_table(df, values='MPG', index='Model Year', columns='Origin', aggfunc='mean')
# Out:
# Origin              1        2          3
# Model Year
# 70          15.272727  25.2000  25.500000
# 71          17.736842  28.7500  29.500000
# 72          16.277778  22.0000  24.200000
# 73          15.034483  24.0000  20.000000
# 74          18.142857  27.0000  29.333333
# 75          17.550000  24.5000  27.500000
# 76          19.431818  24.2500  28.000000
# 77          20.722222  29.2500  27.416667
# 78          21.772727  24.9500  29.687500
# 79          23.478261  30.4500  32.950000
# 80          26.300000  36.8375  35.400000
# 81          27.530769  30.6000  32.958333
# 82          29.789474  40.0000  34.888889
